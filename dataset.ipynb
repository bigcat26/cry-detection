# %%
from dataset.cry import CryDataset

# dataset = ESC50Dataset('E:/dataset/out/temp/training128mel1.pkl')
# dataset = ESC50Dataset('./data/training128mel1.pkl')
dataset = CryDataset('E:/dataset/out/dnac/donateacry.pkl')

# %%
from utils.dataset import dump_dataset_info

dump_dataset_info(dataset)
# print('dataset info')
# print(f'records: {len(dataset)}')

# x, y = dataset[0]
# print(f'data shape: {x.shape}')
# print(f'data label: {y}')

# # count samples for each class
# classes = {}
# for x, y in dataset:
#     classes.setdefault(y, 0)
#     classes[y] += 1

# # classes = sorted(classes.keys(), key=lambda x: x[1], reverse=True)
# classes = sorted(classes.items(), key=lambda x: x[0])
# for key, value in classes:
#     print(f'class[{key}] items: {value}')
# Out:
# dataset info
# records: 6227
# data shape: torch.Size([128, 256])
# data label: 0
# class[0] items: 569
# class[1] items: 1097
# class[2] items: 169
# class[3] items: 87
# class[4] items: 288
# class[5] items: 3775
# class[6] items: 242

# %%
import matplotlib.pyplot as plt

plt.pcolormesh(x, cmap='gray')
plt.show()
